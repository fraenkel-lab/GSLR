# %% [markdown]
# # Downloading/Pre-processing KEGG gene lists

# %%
from urllib.request import urlopen
import numpy as np
import pandas as pd
import pickle

# %% [markdown]
# ## I. Get all human pathway IDs

# %%
list_human_KEGG_pathways_url = "http://rest.kegg.jp/list/pathway/hsa"
human_KEGG_pathways = urlopen(list_human_KEGG_pathways_url, timeout=20).read().decode()
lines = human_KEGG_pathways.split(" - Homo sapiens (human)\n")
lines = [line.split('\t')[0] for line in lines]
lines = lines[:-1]  # last entry is empty string
pathway_ids = [line.split(':')[1] for line in lines]

print(str(len(pathway_ids))+" pathways found\n")
print(pathway_ids)
# Out:
# 319 pathways found
#
# ['hsa00010', 'hsa00020', 'hsa00030', 'hsa00040', 'hsa00051', 'hsa00052', 'hsa00053', 'hsa00061', 'hsa00062', 'hsa00071', 'hsa00072', 'hsa00100', 'hsa00120', 'hsa00130', 'hsa00140', 'hsa00190', 'hsa00220', 'hsa00230', 'hsa00232', 'hsa00240', 'hsa00250', 'hsa00260', 'hsa00270', 'hsa00280', 'hsa00290', 'hsa00310', 'hsa00330', 'hsa00340', 'hsa00350', 'hsa00360', 'hsa00380', 'hsa00400', 'hsa00410', 'hsa00430', 'hsa00440', 'hsa00450', 'hsa00471', 'hsa00472', 'hsa00480', 'hsa00500', 'hsa00510', 'hsa00511', 'hsa00512', 'hsa00514', 'hsa00515', 'hsa00520', 'hsa00524', 'hsa00531', 'hsa00532', 'hsa00533', 'hsa00534', 'hsa00561', 'hsa00562', 'hsa00563', 'hsa00564', 'hsa00565', 'hsa00590', 'hsa00591', 'hsa00592', 'hsa00600', 'hsa00601', 'hsa00603', 'hsa00604', 'hsa00620', 'hsa00630', 'hsa00640', 'hsa00650', 'hsa00670', 'hsa00730', 'hsa00740', 'hsa00750', 'hsa00760', 'hsa00770', 'hsa00780', 'hsa00785', 'hsa00790', 'hsa00830', 'hsa00860', 'hsa00900', 'hsa00910', 'hsa00920', 'hsa00970', 'hsa00980', 'hsa00982', 'hsa00983', 'hsa01040', 'hsa01100', 'hsa01200', 'hsa01210', 'hsa01212', 'hsa01230', 'hsa01521', 'hsa01522', 'hsa01523', 'hsa01524', 'hsa02010', 'hsa03008', 'hsa03010', 'hsa03013', 'hsa03015', 'hsa03018', 'hsa03020', 'hsa03022', 'hsa03030', 'hsa03040', 'hsa03050', 'hsa03060', 'hsa03320', 'hsa03410', 'hsa03420', 'hsa03430', 'hsa03440', 'hsa03450', 'hsa03460', 'hsa04010', 'hsa04012', 'hsa04014', 'hsa04015', 'hsa04020', 'hsa04022', 'hsa04024', 'hsa04060', 'hsa04062', 'hsa04064', 'hsa04066', 'hsa04068', 'hsa04070', 'hsa04071', 'hsa04072', 'hsa04080', 'hsa04110', 'hsa04114', 'hsa04115', 'hsa04120', 'hsa04122', 'hsa04130', 'hsa04136', 'hsa04137', 'hsa04140', 'hsa04141', 'hsa04142', 'hsa04144', 'hsa04145', 'hsa04146', 'hsa04150', 'hsa04151', 'hsa04152', 'hsa04210', 'hsa04211', 'hsa04213', 'hsa04215', 'hsa04216', 'hsa04217', 'hsa04218', 'hsa04260', 'hsa04261', 'hsa04270', 'hsa04310', 'hsa04330', 'hsa04340', 'hsa04350', 'hsa04360', 'hsa04370', 'hsa04371', 'hsa04380', 'hsa04390', 'hsa04392', 'hsa04510', 'hsa04512', 'hsa04514', 'hsa04520', 'hsa04530', 'hsa04540', 'hsa04550', 'hsa04610', 'hsa04611', 'hsa04612', 'hsa04614', 'hsa04620', 'hsa04621', 'hsa04622', 'hsa04623', 'hsa04630', 'hsa04640', 'hsa04650', 'hsa04657', 'hsa04658', 'hsa04659', 'hsa04660', 'hsa04662', 'hsa04664', 'hsa04666', 'hsa04668', 'hsa04670', 'hsa04672', 'hsa04710', 'hsa04713', 'hsa04720', 'hsa04721', 'hsa04722', 'hsa04723', 'hsa04724', 'hsa04725', 'hsa04726', 'hsa04727', 'hsa04728', 'hsa04730', 'hsa04740', 'hsa04742', 'hsa04744', 'hsa04750', 'hsa04810', 'hsa04910', 'hsa04911', 'hsa04912', 'hsa04913', 'hsa04914', 'hsa04915', 'hsa04916', 'hsa04917', 'hsa04918', 'hsa04919', 'hsa04920', 'hsa04921', 'hsa04922', 'hsa04923', 'hsa04924', 'hsa04925', 'hsa04930', 'hsa04931', 'hsa04932', 'hsa04933', 'hsa04940', 'hsa04950', 'hsa04960', 'hsa04961', 'hsa04962', 'hsa04964', 'hsa04966', 'hsa04970', 'hsa04971', 'hsa04972', 'hsa04973', 'hsa04974', 'hsa04975', 'hsa04976', 'hsa04977', 'hsa04978', 'hsa05010', 'hsa05012', 'hsa05014', 'hsa05016', 'hsa05020', 'hsa05030', 'hsa05031', 'hsa05032', 'hsa05033', 'hsa05034', 'hsa05100', 'hsa05110', 'hsa05120', 'hsa05130', 'hsa05131', 'hsa05132', 'hsa05133', 'hsa05134', 'hsa05140', 'hsa05142', 'hsa05143', 'hsa05144', 'hsa05145', 'hsa05146', 'hsa05150', 'hsa05152', 'hsa05160', 'hsa05161', 'hsa05162', 'hsa05164', 'hsa05165', 'hsa05166', 'hsa05167', 'hsa05168', 'hsa05169', 'hsa05200', 'hsa05202', 'hsa05203', 'hsa05204', 'hsa05205', 'hsa05206', 'hsa05210', 'hsa05211', 'hsa05212', 'hsa05213', 'hsa05214', 'hsa05215', 'hsa05216', 'hsa05217', 'hsa05218', 'hsa05219', 'hsa05220', 'hsa05221', 'hsa05222', 'hsa05223', 'hsa05224', 'hsa05230', 'hsa05231', 'hsa05310', 'hsa05320', 'hsa05321', 'hsa05322', 'hsa05323', 'hsa05330', 'hsa05332', 'hsa05340', 'hsa05410', 'hsa05412', 'hsa05414', 'hsa05416', 'hsa05418']

# %% [markdown]
# ## II. Get Annotations for each KEGG pathway

# %%
def get_KEGG_pathway_data(pathway_id):
    pathway_annotations_url = "http://rest.kegg.jp/get/"+pathway_id
    response = urlopen(pathway_annotations_url, timeout=20).read().decode()
    lines = response.split('\n') 
    metadata = [line[12:].split(' - Homo')[0] for line in lines if line.startswith('NAME') or line.startswith('CLASS')]
    
    print(metadata)
    
    if len(metadata) < 2: 
        print("\nNO CATEGORY PROVIDED FOR PATHWAY "+pathway_id+"\n")
        return
    
    start = response.find("GENE")
    end = response.find("COMPOUND")
    if end == -1: end = response.find("KO_PATHWAY")
    if end == -1: end = response.find("REFERENCE")
    if end == -1: print(url_path_genes)
    # adjust
    end -= 1
    
    gene_text = response[start:end]
    lines = gene_text.split('\n')
    genes = []
    for line in lines:
        if len(line.split(';')) > 1:
            tmp = line.split(';')[0]
            tmp = tmp.lstrip(' ')
            gene = tmp.split(' ')[-1]
            genes.append(gene) 
    
    
    return {'id': pathway_id, 'name': metadata[0], 'class': metadata[1], 'genes': genes}

pathways = [get_KEGG_pathway_data(pathway_id) for pathway_id in pathway_ids]
# Out:
# ['Glycolysis / Gluconeogenesis', 'Metabolism; Carbohydrate metabolism']
# ['Citrate cycle (TCA cycle)', 'Metabolism; Carbohydrate metabolism']
# ['Pentose phosphate pathway', 'Metabolism; Carbohydrate metabolism']
# ['Pentose and glucuronate interconversions', 'Metabolism; Carbohydrate metabolism']
# ['Fructose and mannose metabolism', 'Metabolism; Carbohydrate metabolism']
# ['Galactose metabolism', 'Metabolism; Carbohydrate metabolism']
# ['Ascorbate and aldarate metabolism', 'Metabolism; Carbohydrate metabolism']
# ['Fatty acid biosynthesis', 'Metabolism; Lipid metabolism']
# ['Fatty acid elongation', 'Metabolism; Lipid metabolism']
# ['Fatty acid degradation', 'Metabolism; Lipid metabolism']
# ['Synthesis and degradation of ketone bodies', 'Metabolism; Lipid metabolism']
# ['Steroid biosynthesis', 'Metabolism; Lipid metabolism']
# ['Primary bile acid biosynthesis', 'Metabolism; Lipid metabolism']
# ['Ubiquinone and other terpenoid-quinone biosynthesis', 'Metabolism; Metabolism of cofactors and vitamins']
# ['Steroid hormone biosynthesis', 'Metabolism; Lipid metabolism']
# ['Oxidative phosphorylation', 'Metabolism; Energy metabolism']
# ['Arginine biosynthesis', 'Metabolism; Amino acid metabolism']
# ['Purine metabolism', 'Metabolism; Nucleotide metabolism']
# ['Caffeine metabolism', 'Metabolism; Biosynthesis of other secondary metabolites']
# ['Pyrimidine metabolism', 'Metabolism; Nucleotide metabolism']
# ['Alanine, aspartate and glutamate metabolism', 'Metabolism; Amino acid metabolism']
# ['Glycine, serine and threonine metabolism', 'Metabolism; Amino acid metabolism']
# ['Cysteine and methionine metabolism', 'Metabolism; Amino acid metabolism']
# ['Valine, leucine and isoleucine degradation', 'Metabolism; Amino acid metabolism']
# ['Valine, leucine and isoleucine biosynthesis', 'Metabolism; Amino acid metabolism']
# ['Lysine degradation', 'Metabolism; Amino acid metabolism']
# ['Arginine and proline metabolism', 'Metabolism; Amino acid metabolism']
# ['Histidine metabolism', 'Metabolism; Amino acid metabolism']
# ['Tyrosine metabolism', 'Metabolism; Amino acid metabolism']
# ['Phenylalanine metabolism', 'Metabolism; Amino acid metabolism']
# ['Tryptophan metabolism', 'Metabolism; Amino acid metabolism']
# ['Phenylalanine, tyrosine and tryptophan biosynthesis', 'Metabolism; Amino acid metabolism']
# ['beta-Alanine metabolism', 'Metabolism; Metabolism of other amino acids']
# ['Taurine and hypotaurine metabolism', 'Metabolism; Metabolism of other amino acids']
# ['Phosphonate and phosphinate metabolism', 'Metabolism; Metabolism of other amino acids']
# ['Selenocompound metabolism', 'Metabolism; Metabolism of other amino acids']
# ['D-Glutamine and D-glutamate metabolism', 'Metabolism; Metabolism of other amino acids']
# ['D-Arginine and D-ornithine metabolism', 'Metabolism; Metabolism of other amino acids']
# ['Glutathione metabolism', 'Metabolism; Metabolism of other amino acids']
# ['Starch and sucrose metabolism', 'Metabolism; Carbohydrate metabolism']
# ['N-Glycan biosynthesis', 'Metabolism; Glycan biosynthesis and metabolism']
# ['Other glycan degradation', 'Metabolism; Glycan biosynthesis and metabolism']
# ['Mucin type O-glycan biosynthesis', 'Metabolism; Glycan biosynthesis and metabolism']
# ['Other types of O-glycan biosynthesis', 'Metabolism; Glycan biosynthesis and metabolism']
# ['Mannose type O-glycan biosynthesis', 'Metabolism; Glycan biosynthesis and metabolism']
# ['Amino sugar and nucleotide sugar metabolism', 'Metabolism; Carbohydrate metabolism']
# ['Neomycin, kanamycin and gentamicin biosynthesis', 'Metabolism; Biosynthesis of other secondary metabolites']
# ['Glycosaminoglycan degradation', 'Metabolism; Glycan biosynthesis and metabolism']
# ['Glycosaminoglycan biosynthesis - chondroitin sulfate / dermatan sulfate', 'Metabolism; Glycan biosynthesis and metabolism']
# ['Glycosaminoglycan biosynthesis - keratan sulfate', 'Metabolism; Glycan biosynthesis and metabolism']
# ['Glycosaminoglycan biosynthesis - heparan sulfate / heparin', 'Metabolism; Glycan biosynthesis and metabolism']
# ['Glycerolipid metabolism', 'Metabolism; Lipid metabolism']
# ['Inositol phosphate metabolism', 'Metabolism; Carbohydrate metabolism']
# ['Glycosylphosphatidylinositol (GPI)-anchor biosynthesis', 'Metabolism; Glycan biosynthesis and metabolism']
# ['Glycerophospholipid metabolism', 'Metabolism; Lipid metabolism']
# ['Ether lipid metabolism', 'Metabolism; Lipid metabolism']
# ['Arachidonic acid metabolism', 'Metabolism; Lipid metabolism']
# ['Linoleic acid metabolism', 'Metabolism; Lipid metabolism']
# ['alpha-Linolenic acid metabolism', 'Metabolism; Lipid metabolism']
# ['Sphingolipid metabolism', 'Metabolism; Lipid metabolism']
# ['Glycosphingolipid biosynthesis - lacto and neolacto series', 'Metabolism; Glycan biosynthesis and metabolism']
# ['Glycosphingolipid biosynthesis - globo and isoglobo series', 'Metabolism; Glycan biosynthesis and metabolism']
# ['Glycosphingolipid biosynthesis - ganglio series', 'Metabolism; Glycan biosynthesis and metabolism']
# ['Pyruvate metabolism', 'Metabolism; Carbohydrate metabolism']
# ['Glyoxylate and dicarboxylate metabolism', 'Metabolism; Carbohydrate metabolism']
# ['Propanoate metabolism', 'Metabolism; Carbohydrate metabolism']
# ['Butanoate metabolism', 'Metabolism; Carbohydrate metabolism']
# ['One carbon pool by folate', 'Metabolism; Metabolism of cofactors and vitamins']
# ['Thiamine metabolism', 'Metabolism; Metabolism of cofactors and vitamins']
# ['Riboflavin metabolism', 'Metabolism; Metabolism of cofactors and vitamins']
# ['Vitamin B6 metabolism', 'Metabolism; Metabolism of cofactors and vitamins']
# ['Nicotinate and nicotinamide metabolism', 'Metabolism; Metabolism of cofactors and vitamins']
# ['Pantothenate and CoA biosynthesis', 'Metabolism; Metabolism of cofactors and vitamins']
# ['Biotin metabolism', 'Metabolism; Metabolism of cofactors and vitamins']
# ['Lipoic acid metabolism', 'Metabolism; Metabolism of cofactors and vitamins']
# ['Folate biosynthesis', 'Metabolism; Metabolism of cofactors and vitamins']
# ['Retinol metabolism', 'Metabolism; Metabolism of cofactors and vitamins']
# ['Porphyrin and chlorophyll metabolism', 'Metabolism; Metabolism of cofactors and vitamins']
# ['Terpenoid backbone biosynthesis', 'Metabolism; Metabolism of terpenoids and polyketides']
# ['Nitrogen metabolism', 'Metabolism; Energy metabolism']
# ['Sulfur metabolism', 'Metabolism; Energy metabolism']
# ['Aminoacyl-tRNA biosynthesis', 'Genetic Information Processing; Translation']
# ['Metabolism of xenobiotics by cytochrome P450', 'Metabolism; Xenobiotics biodegradation and metabolism']
# ['Drug metabolism - cytochrome P450', 'Metabolism; Xenobiotics biodegradation and metabolism']
# ['Drug metabolism - other enzymes', 'Metabolism; Xenobiotics biodegradation and metabolism']
# ['Biosynthesis of unsaturated fatty acids', 'Metabolism; Lipid metabolism']
# ['Metabolic pathways']
#
# NO CATEGORY PROVIDED FOR PATHWAY hsa01100
#
# ['Carbon metabolism', 'Metabolism; Overview']
# ['2-Oxocarboxylic acid metabolism', 'Metabolism; Overview']
# ['Fatty acid metabolism', 'Metabolism; Overview']
# ['Biosynthesis of amino acids', 'Metabolism; Overview']
# ['EGFR tyrosine kinase inhibitor resistance', 'Human Diseases; Drug resistance']
# ['Endocrine resistance', 'Human Diseases; Drug resistance']
# ['Antifolate resistance', 'Human Diseases; Drug resistance']
# ['Platinum drug resistance', 'Human Diseases; Drug resistance']
# ['ABC transporters', 'Environmental Information Processing; Membrane transport']
# ['Ribosome biogenesis in eukaryotes', 'Genetic Information Processing; Translation']
# ['Ribosome', 'Genetic Information Processing; Translation']
# ['RNA transport', 'Genetic Information Processing; Translation']
# ['mRNA surveillance pathway', 'Genetic Information Processing; Translation']
# ['RNA degradation', 'Genetic Information Processing; Folding, sorting and degradation']
# ['RNA polymerase', 'Genetic Information Processing; Transcription']
# ['Basal transcription factors', 'Genetic Information Processing; Transcription']
# ['DNA replication', 'Genetic Information Processing; Replication and repair']
# ['Spliceosome', 'Genetic Information Processing; Transcription']
# ['Proteasome', 'Genetic Information Processing; Folding, sorting and degradation']
# ['Protein export', 'Genetic Information Processing; Folding, sorting and degradation']
# ['PPAR signaling pathway', 'Organismal Systems; Endocrine system']
# ['Base excision repair', 'Genetic Information Processing; Replication and repair']
# ['Nucleotide excision repair', 'Genetic Information Processing; Replication and repair']
# ['Mismatch repair', 'Genetic Information Processing; Replication and repair']
# ['Homologous recombination', 'Genetic Information Processing; Replication and repair']
# ['Non-homologous end-joining', 'Genetic Information Processing; Replication and repair']
# ['Fanconi anemia pathway', 'Genetic Information Processing; Replication and repair']
# ['MAPK signaling pathway', 'Environmental Information Processing; Signal transduction']
# ['ErbB signaling pathway', 'Environmental Information Processing; Signal transduction']
# ['Ras signaling pathway', 'Environmental Information Processing; Signal transduction']
# ['Rap1 signaling pathway', 'Environmental Information Processing; Signal transduction']
# ['Calcium signaling pathway', 'Environmental Information Processing; Signal transduction']
# ['cGMP-PKG signaling pathway', 'Environmental Information Processing; Signal transduction']
# ['cAMP signaling pathway', 'Environmental Information Processing; Signal transduction']
# ['Cytokine-cytokine receptor interaction', 'Environmental Information Processing; Signaling molecules and interaction']
# ['Chemokine signaling pathway', 'Organismal Systems; Immune system']
# ['NF-kappa B signaling pathway', 'Environmental Information Processing; Signal transduction']
# ['HIF-1 signaling pathway', 'Environmental Information Processing; Signal transduction']
# ['FoxO signaling pathway', 'Environmental Information Processing; Signal transduction']
# ['Phosphatidylinositol signaling system', 'Environmental Information Processing; Signal transduction']
# ['Sphingolipid signaling pathway', 'Environmental Information Processing; Signal transduction']
# ['Phospholipase D signaling pathway', 'Environmental Information Processing; Signal transduction']
# ['Neuroactive ligand-receptor interaction', 'Environmental Information Processing; Signaling molecules and interaction']
# ['Cell cycle', 'Cellular Processes; Cell growth and death']
# ['Oocyte meiosis', 'Cellular Processes; Cell growth and death']
# ['p53 signaling pathway', 'Cellular Processes; Cell growth and death']
# ['Ubiquitin mediated proteolysis', 'Genetic Information Processing; Folding, sorting and degradation']
# ['Sulfur relay system', 'Genetic Information Processing; Folding, sorting and degradation']
# ['SNARE interactions in vesicular transport', 'Genetic Information Processing; Folding, sorting and degradation']
# ['Autophagy - other', 'Cellular Processes; Transport and catabolism']
# ['Mitophagy - animal', 'Cellular Processes; Transport and catabolism']
# ['Autophagy - animal', 'Cellular Processes; Transport and catabolism']
# ['Protein processing in endoplasmic reticulum', 'Genetic Information Processing; Folding, sorting and degradation']
# ['Lysosome', 'Cellular Processes; Transport and catabolism']
# ['Endocytosis', 'Cellular Processes; Transport and catabolism']
# ['Phagosome', 'Cellular Processes; Transport and catabolism']
# ['Peroxisome', 'Cellular Processes; Transport and catabolism']
# ['mTOR signaling pathway', 'Environmental Information Processing; Signal transduction']
# ['PI3K-Akt signaling pathway', 'Environmental Information Processing; Signal transduction']
# ['AMPK signaling pathway', 'Environmental Information Processing; Signal transduction']
# ['Apoptosis', 'Cellular Processes; Cell growth and death']
# ['Longevity regulating pathway', 'Organismal Systems; Aging']
# ['Longevity regulating pathway - multiple species', 'Organismal Systems; Aging']
# ['Apoptosis - multiple species', 'Cellular Processes; Cell growth and death']
# ['Ferroptosis', 'Cellular Processes; Cell growth and death']
# ['Necroptosis', 'Cellular Processes; Cell growth and death']
# ['Cellular senescence', 'Cellular Processes; Cell growth and death']
# ['Cardiac muscle contraction', 'Organismal Systems; Circulatory system']
# ['Adrenergic signaling in cardiomyocytes', 'Organismal Systems; Circulatory system']
# ['Vascular smooth muscle contraction', 'Organismal Systems; Circulatory system']
# ['Wnt signaling pathway', 'Environmental Information Processing; Signal transduction']
# ['Notch signaling pathway', 'Environmental Information Processing; Signal transduction']
# ['Hedgehog signaling pathway', 'Environmental Information Processing; Signal transduction']
# ['TGF-beta signaling pathway', 'Environmental Information Processing; Signal transduction']
# ['Axon guidance', 'Organismal Systems; Development']
# ['VEGF signaling pathway', 'Environmental Information Processing; Signal transduction']
# ['Apelin signaling pathway', 'Environmental Information Processing; Signal transduction']
# ['Osteoclast differentiation', 'Organismal Systems; Development']
# ['Hippo signaling pathway', 'Environmental Information Processing; Signal transduction']
# ['Hippo signaling pathway - multiple species', 'Environmental Information Processing; Signal transduction']
# ['Focal adhesion', 'Cellular Processes; Cellular community - eukaryotes']
# ['ECM-receptor interaction', 'Environmental Information Processing; Signaling molecules and interaction']
# ['Cell adhesion molecules (CAMs)', 'Environmental Information Processing; Signaling molecules and interaction']
# ['Adherens junction', 'Cellular Processes; Cellular community - eukaryotes']
# ['Tight junction', 'Cellular Processes; Cellular community - eukaryotes']
# ['Gap junction', 'Cellular Processes; Cellular community - eukaryotes']
# ['Signaling pathways regulating pluripotency of stem cells', 'Cellular Processes; Cellular community - eukaryotes']
# ['Complement and coagulation cascades', 'Organismal Systems; Immune system']
# ['Platelet activation', 'Organismal Systems; Immune system']
# ['Antigen processing and presentation', 'Organismal Systems; Immune system']
# ['Renin-angiotensin system', 'Organismal Systems; Endocrine system']
# ['Toll-like receptor signaling pathway', 'Organismal Systems; Immune system']
# ['NOD-like receptor signaling pathway', 'Organismal Systems; Immune system']
# ['RIG-I-like receptor signaling pathway', 'Organismal Systems; Immune system']
# ['Cytosolic DNA-sensing pathway', 'Organismal Systems; Immune system']
# ['Jak-STAT signaling pathway', 'Environmental Information Processing; Signal transduction']
# ['Hematopoietic cell lineage', 'Organismal Systems; Immune system']
# ['Natural killer cell mediated cytotoxicity', 'Organismal Systems; Immune system']
# ['IL-17 signaling pathway', 'Organismal Systems; Immune system']
# ['Th1 and Th2 cell differentiation', 'Organismal Systems; Immune system']
# ['Th17 cell differentiation', 'Organismal Systems; Immune system']
# ['T cell receptor signaling pathway', 'Organismal Systems; Immune system']
# ['B cell receptor signaling pathway', 'Organismal Systems; Immune system']
# ['Fc epsilon RI signaling pathway', 'Organismal Systems; Immune system']
# ['Fc gamma R-mediated phagocytosis', 'Organismal Systems; Immune system']
# ['TNF signaling pathway', 'Environmental Information Processing; Signal transduction']
# ['Leukocyte transendothelial migration', 'Organismal Systems; Immune system']
# ['Intestinal immune network for IgA production', 'Organismal Systems; Immune system']
# ['Circadian rhythm', 'Organismal Systems; Environmental adaptation']
# ['Circadian entrainment', 'Organismal Systems; Environmental adaptation']
# ['Long-term potentiation', 'Organismal Systems; Nervous system']
# ['Synaptic vesicle cycle', 'Organismal Systems; Nervous system']
# ['Neurotrophin signaling pathway', 'Organismal Systems; Nervous system']
# ['Retrograde endocannabinoid signaling', 'Organismal Systems; Nervous system']
# ['Glutamatergic synapse', 'Organismal Systems; Nervous system']
# ['Cholinergic synapse', 'Organismal Systems; Nervous system']
# ['Serotonergic synapse', 'Organismal Systems; Nervous system']
# ['GABAergic synapse', 'Organismal Systems; Nervous system']
# ['Dopaminergic synapse', 'Organismal Systems; Nervous system']
# ['Long-term depression', 'Organismal Systems; Nervous system']
# ['Olfactory transduction', 'Organismal Systems; Sensory system']
# ['Taste transduction', 'Organismal Systems; Sensory system']
# ['Phototransduction', 'Organismal Systems; Sensory system']
# ['Inflammatory mediator regulation of TRP channels', 'Organismal Systems; Sensory system']
# ['Regulation of actin cytoskeleton', 'Cellular Processes; Cell motility']
# ['Insulin signaling pathway', 'Organismal Systems; Endocrine system']
# ['Insulin secretion', 'Organismal Systems; Endocrine system']
# ['GnRH signaling pathway', 'Organismal Systems; Endocrine system']
# ['Ovarian steroidogenesis', 'Organismal Systems; Endocrine system']
# ['Progesterone-mediated oocyte maturation', 'Organismal Systems; Endocrine system']
# ['Estrogen signaling pathway', 'Organismal Systems; Endocrine system']
# ['Melanogenesis', 'Organismal Systems; Endocrine system']
# ['Prolactin signaling pathway', 'Organismal Systems; Endocrine system']
# ['Thyroid hormone synthesis', 'Organismal Systems; Endocrine system']
# ['Thyroid hormone signaling pathway', 'Organismal Systems; Endocrine system']
# ['Adipocytokine signaling pathway', 'Organismal Systems; Endocrine system']
# ['Oxytocin signaling pathway', 'Organismal Systems; Endocrine system']
# ['Glucagon signaling pathway', 'Organismal Systems; Endocrine system']
# ['Regulation of lipolysis in adipocytes', 'Organismal Systems; Endocrine system']
# ['Renin secretion', 'Organismal Systems; Endocrine system']
# ['Aldosterone synthesis and secretion', 'Organismal Systems; Endocrine system']
# ['Type II diabetes mellitus', 'Human Diseases; Endocrine and metabolic diseases']
# ['Insulin resistance', 'Human Diseases; Endocrine and metabolic diseases']
# ['Non-alcoholic fatty liver disease (NAFLD)', 'Human Diseases; Endocrine and metabolic diseases']
# ['AGE-RAGE signaling pathway in diabetic complications', 'Human Diseases; Endocrine and metabolic diseases']
# ['Type I diabetes mellitus', 'Human Diseases; Endocrine and metabolic diseases']
# ['Maturity onset diabetes of the young', 'Human Diseases; Endocrine and metabolic diseases']
# ['Aldosterone-regulated sodium reabsorption', 'Organismal Systems; Excretory system']
# ['Endocrine and other factor-regulated calcium reabsorption', 'Organismal Systems; Excretory system']
# ['Vasopressin-regulated water reabsorption', 'Organismal Systems; Excretory system']
# ['Proximal tubule bicarbonate reclamation', 'Organismal Systems; Excretory system']
# ['Collecting duct acid secretion', 'Organismal Systems; Excretory system']
# ['Salivary secretion', 'Organismal Systems; Digestive system']
# ['Gastric acid secretion', 'Organismal Systems; Digestive system']
# ['Pancreatic secretion', 'Organismal Systems; Digestive system']
# ['Carbohydrate digestion and absorption', 'Organismal Systems; Digestive system']
# ['Protein digestion and absorption', 'Organismal Systems; Digestive system']
# ['Fat digestion and absorption', 'Organismal Systems; Digestive system']
# ['Bile secretion', 'Organismal Systems; Digestive system']
# ['Vitamin digestion and absorption', 'Organismal Systems; Digestive system']
# ['Mineral absorption', 'Organismal Systems; Digestive system']
# ["Alzheimer's disease", 'Human Diseases; Neurodegenerative diseases']
# ["Parkinson's disease", 'Human Diseases; Neurodegenerative diseases']
# ['Amyotrophic lateral sclerosis (ALS)', 'Human Diseases; Neurodegenerative diseases']
# ["Huntington's disease", 'Human Diseases; Neurodegenerative diseases']
# ['Prion diseases', 'Human Diseases; Neurodegenerative diseases']
# ['Cocaine addiction', 'Human Diseases; Substance dependence']
# ['Amphetamine addiction', 'Human Diseases; Substance dependence']
# ['Morphine addiction', 'Human Diseases; Substance dependence']
# ['Nicotine addiction', 'Human Diseases; Substance dependence']
# ['Alcoholism', 'Human Diseases; Substance dependence']
# ['Bacterial invasion of epithelial cells', 'Human Diseases; Infectious diseases']
# ['Vibrio cholerae infection', 'Human Diseases; Infectious diseases']
# ['Epithelial cell signaling in Helicobacter pylori infection', 'Human Diseases; Infectious diseases']
# ['Pathogenic Escherichia coli infection', 'Human Diseases; Infectious diseases']
# ['Shigellosis', 'Human Diseases; Infectious diseases']
# ['Salmonella infection', 'Human Diseases; Infectious diseases']
# ['Pertussis', 'Human Diseases; Infectious diseases']
# ['Legionellosis', 'Human Diseases; Infectious diseases']
# ['Leishmaniasis', 'Human Diseases; Infectious diseases']
# ['Chagas disease (American trypanosomiasis)', 'Human Diseases; Infectious diseases']
# ['African trypanosomiasis', 'Human Diseases; Infectious diseases']
# ['Malaria', 'Human Diseases; Infectious diseases']
# ['Toxoplasmosis', 'Human Diseases; Infectious diseases']
# ['Amoebiasis', 'Human Diseases; Infectious diseases']
# ['Staphylococcus aureus infection', 'Human Diseases; Infectious diseases']
# ['Tuberculosis', 'Human Diseases; Infectious diseases']
# ['Hepatitis C', 'Human Diseases; Infectious diseases']
# ['Hepatitis B', 'Human Diseases; Infectious diseases']
# ['Measles', 'Human Diseases; Infectious diseases']
# ['Influenza A', 'Human Diseases; Infectious diseases']
# ['Human papillomavirus infection', 'Human Diseases; Infectious diseases']
# ['HTLV-I infection', 'Human Diseases; Infectious diseases']
# ["Kaposi's sarcoma-associated herpesvirus infection", 'Human Diseases; Infectious diseases']
# ['Herpes simplex infection', 'Human Diseases; Infectious diseases']
# ['Epstein-Barr virus infection', 'Human Diseases; Infectious diseases']
# ['Pathways in cancer', 'Human Diseases; Cancers']
# ['Transcriptional misregulation in cancer', 'Human Diseases; Cancers']
# ['Viral carcinogenesis', 'Human Diseases; Cancers']
# ['Chemical carcinogenesis', 'Human Diseases; Cancers']
# ['Proteoglycans in cancer', 'Human Diseases; Cancers']
# ['MicroRNAs in cancer', 'Human Diseases; Cancers']
# ['Colorectal cancer', 'Human Diseases; Cancers']
# ['Renal cell carcinoma', 'Human Diseases; Cancers']
# ['Pancreatic cancer', 'Human Diseases; Cancers']
# ['Endometrial cancer', 'Human Diseases; Cancers']
# ['Glioma', 'Human Diseases; Cancers']
# ['Prostate cancer', 'Human Diseases; Cancers']
# ['Thyroid cancer', 'Human Diseases; Cancers']
# ['Basal cell carcinoma', 'Human Diseases; Cancers']
# ['Melanoma', 'Human Diseases; Cancers']
# ['Bladder cancer', 'Human Diseases; Cancers']
# ['Chronic myeloid leukemia', 'Human Diseases; Cancers']
# ['Acute myeloid leukemia', 'Human Diseases; Cancers']
# ['Small cell lung cancer', 'Human Diseases; Cancers']
# ['Non-small cell lung cancer', 'Human Diseases; Cancers']
# ['Breast cancer', 'Human Diseases; Cancers']
# ['Central carbon metabolism in cancer', 'Human Diseases; Cancers']
# ['Choline metabolism in cancer', 'Human Diseases; Cancers']
# ['Asthma', 'Human Diseases; Immune diseases']
# ['Autoimmune thyroid disease', 'Human Diseases; Immune diseases']
# ['Inflammatory bowel disease (IBD)', 'Human Diseases; Immune diseases']
# ['Systemic lupus erythematosus', 'Human Diseases; Immune diseases']
# ['Rheumatoid arthritis', 'Human Diseases; Immune diseases']
# ['Allograft rejection', 'Human Diseases; Immune diseases']
# ['Graft-versus-host disease', 'Human Diseases; Immune diseases']
# ['Primary immunodeficiency', 'Human Diseases; Immune diseases']
# ['Hypertrophic cardiomyopathy (HCM)', 'Human Diseases; Cardiovascular diseases']
# ['Arrhythmogenic right ventricular cardiomyopathy (ARVC)', 'Human Diseases; Cardiovascular diseases']
# ['Dilated cardiomyopathy (DCM)', 'Human Diseases; Cardiovascular diseases']
# ['Viral myocarditis', 'Human Diseases; Cardiovascular diseases']
# ['Fluid shear stress and atherosclerosis', 'Human Diseases; Cardiovascular diseases']

# %% [markdown]
# ## III. Build a dataframe

# %%
pathways_df = pd.DataFrame([pathway for pathway in pathways if pathway != None])
pathways_df.head()
# Out:
#                                  class  \
# 0  Metabolism; Carbohydrate metabolism
# 1  Metabolism; Carbohydrate metabolism
# 2  Metabolism; Carbohydrate metabolism
# 3  Metabolism; Carbohydrate metabolism
# 4  Metabolism; Carbohydrate metabolism
#
#                                                genes        id  \
# 0  [HK3, HK1, HK2, HKDC1, GCK, GPI, PFKM, PFKP, P...  hsa00010
# 1  [CS, ACLY, ACO2, ACO1, IDH1, IDH2, IDH3B, IDH3...  hsa00020
# 2  [GPI, G6PD, PGLS, H6PD, PGD, RPE, RPEL1, TKT, ...  hsa00030
# 3  [GUSB, KL, UGT2A1, UGT2A3, UGT2B17, UGT2B11, U...  hsa00040
# 4  [MPI, PMM2, PMM1, GMPPB, GMPPA, GMDS, TSTA3, F...  hsa00051
#
#                                        name
# 0              Glycolysis / Gluconeogenesis
# 1                 Citrate cycle (TCA cycle)
# 2                 Pentose phosphate pathway
# 3  Pentose and glucuronate interconversions
# 4           Fructose and mannose metabolism

# %%
pathways_df['class'], pathways_df['subclass'] = pathways_df['class'].str.split(';', 1).str
pathways_df
# Out:
#               class                                              genes  \
# 0        Metabolism  [HK3, HK1, HK2, HKDC1, GCK, GPI, PFKM, PFKP, P...
# 1        Metabolism  [CS, ACLY, ACO2, ACO1, IDH1, IDH2, IDH3B, IDH3...
# 2        Metabolism  [GPI, G6PD, PGLS, H6PD, PGD, RPE, RPEL1, TKT, ...
# 3        Metabolism  [GUSB, KL, UGT2A1, UGT2A3, UGT2B17, UGT2B11, U...
# 4        Metabolism  [MPI, PMM2, PMM1, GMPPB, GMPPA, GMDS, TSTA3, F...
# 5        Metabolism  [GALM, GALK1, GALT, GALE, UGP2, PGM1, PGM2, HK...
# 6        Metabolism  [UGDH, UGT2A1, UGT2A3, UGT2B17, UGT2B11, UGT2B...
# 7        Metabolism  [ACACA, ACACB, MCAT, FASN, OXSM, OLAH, ACSL6, ...
# 8        Metabolism  [ACAA2, HADHB, HADH, HADHA, ECHS1, MECR, PPT1,...
# 9        Metabolism  [ACAT2, ACAT1, ACAA1, ACAA2, HADHB, HADH, HADH...
# 10       Metabolism  [HMGCS1, HMGCS2, HMGCL, HMGCLL1, OXCT1, OXCT2,...
# 11       Metabolism  [FDFT1, SQLE, LSS, CYP51A1, TM7SF2, MSMO1, FAX...
# 12       Metabolism  [CYP46A1, CYP39A1, HSD3B7, CH25H, CYP7B1, CYP7...
# 13       Metabolism  [TAT, COQ2, COQ3, COQ6, COQ5, COQ7, NQO1, GGCX...
# 14       Metabolism  [CYP11A1, CYP17A1, STS, SULT2B1, CYP21A2, HSD3...
# 15       Metabolism  [ND1, ND2, ND3, ND4, ND4L, ND5, ND6, NDUFS1, N...
# 16       Metabolism  [OTC, ASS1, ASL, ARG2, ARG1, NOS1, NOS2, NOS3,...
# 17       Metabolism  [NUDT9, ADPRM, NUDT5, PGM1, PGM2, PRPS1L1, PRP...
# 18       Metabolism                  [CYP1A2, NAT2, NAT1, CYP2A6, XDH]
# 19       Metabolism  [CAD, DHODH, UMPS, CMPK1, CMPK2, NME6, NME7, N...
# 20       Metabolism  [GOT1, GOT2, IL4I1, DDO, ASNS, NIT2, GPT2, GPT...
# 21       Metabolism  [SHMT2, SHMT1, AGXT, GRHPR, GLYCTK, PGAM1, PGA...
# 22       Metabolism  [CTH, CBS, CBSL, BHMT, BHMT2, MTR, MAT2B, MAT1...
# 23       Metabolism  [BCAT2, BCAT1, IL4I1, BCKDHA, BCKDHB, DBT, DLD...
# 24       Metabolism                          [SDS, SDSL, BCAT2, BCAT1]
# 25       Metabolism  [AASS, ALDH7A1, AADAT, OGDHL, OGDH, DLST, GCDH...
# 26       Metabolism  [GATM, GAMT, CKM, CKMT1A, CKMT2, CKB, CKMT1B, ...
# 27       Metabolism  [HAL, UROC1, AMDHD1, FTCD, HDC, DDC, AOC1, ALD...
# 28       Metabolism  [GOT1, GOT2, TAT, IL4I1, HPD, HGD, GSTZ1, FAH,...
# 29       Metabolism  [PAH, DDC, AOC3, AOC2, MAOB, MAOA, ALDH3B1, AL...
# ..              ...                                                ...
# 288  Human Diseases  [GSK3B, AXIN1, AXIN2, CTNNB1, APC, APC2, TCF7,...
# 289  Human Diseases  [HIF1A, EPAS1, EGLN1, EGLN3, EGLN2, VHL, ELOC,...
# 290  Human Diseases  [KRAS, PIK3CA, PIK3CD, PIK3CB, PIK3R1, PIK3R2,...
# 291  Human Diseases  [EGF, EGFR, PIK3CA, PIK3CD, PIK3CB, PIK3R1, PI...
# 292  Human Diseases  [EGF, TGFA, EGFR, PDGFA, PDGFB, PDGFRA, PDGFRB...
# 293  Human Diseases  [CDKN1B, CDK2, CCNE1, CCNE2, RB1, E2F1, E2F2, ...
# 294  Human Diseases  [RET, CCDC6, NCOA4, NTRK1, TPM3, TPR, TFG, HRA...
# 295  Human Diseases  [TP53, SHH, PTCH1, SMO, KIF7, SUFU, GLI1, GLI2...
# 296  Human Diseases  [FGF1, FGF2, FGF3, FGF4, FGF17, FGF6, FGF7, FG...
# 297  Human Diseases  [FGFR3, HRAS, KRAS, NRAS, ARAF, BRAF, RAF1, MA...
# 298  Human Diseases  [BCR, ABL1, CRK, CRKL, CBLC, CBL, CBLB, PIK3CA...
# 299  Human Diseases  [KIT, FLT3, PIK3CA, PIK3CD, PIK3CB, PIK3R1, PI...
# 300  Human Diseases  [FHIT, RARB, RXRA, RXRB, RXRG, TP53, BCL2, CYC...
# 301  Human Diseases  [FHIT, RARB, RXRA, RXRB, RXRG, CDKN2A, CDK4, C...
# 302  Human Diseases  [ESR1, ESR2, NCOA1, NCOA3, FOS, JUN, SP1, CCND...
# 303  Human Diseases  [SLC2A1, SLC2A2, GCK, PKM, PDHA2, PDHA1, PDHB,...
# 304  Human Diseases  [EGF, PDGFA, PDGFB, PDGFC, PDGFD, EGFR, PDGFRA...
# 305  Human Diseases  [HLA-DMA, HLA-DMB, HLA-DOA, HLA-DOB, HLA-DPA1,...
# 306  Human Diseases  [IFNA1, IFNA2, IFNA4, IFNA5, IFNA6, IFNA7, IFN...
# 307  Human Diseases  [TLR2, TLR4, TLR5, NFKB1, RELA, NOD2, HLA-DMA,...
# 308  Human Diseases  [C1QA, C1QB, C1QC, C2, C4A, C4B, H2AFX, HIST2H...
# 309  Human Diseases  [CD80, CD86, CD28, CTLA4, HLA-DMA, HLA-DMB, HL...
# 310  Human Diseases  [HLA-A, HLA-B, HLA-C, HLA-F, HLA-G, HLA-E, CD8...
# 311  Human Diseases  [IL6, IL1A, IL1B, TNF, HLA-DMA, HLA-DMB, HLA-D...
# 312  Human Diseases  [ADA, IL7R, IL2RG, DCLRE1C, RAG1, RAG2, CD3D, ...
# 313  Human Diseases  [ITGA1, ITGA2, ITGA2B, ITGA3, ITGA4, ITGA5, IT...
# 314  Human Diseases  [ITGA1, ITGA2, ITGA2B, ITGA3, ITGA4, ITGA5, IT...
# 315  Human Diseases  [ITGA1, ITGA2, ITGA2B, ITGA3, ITGA4, ITGA5, IT...
# 316  Human Diseases  [CXADR, CD55, FYN, CAV1, ABL1, ABL2, RAC1, RAC...
# 317  Human Diseases  [HSP90AA1, HSP90AB1, HSP90B1, NOS3, CAV1, CAV2...
#
#            id                                               name  \
# 0    hsa00010                       Glycolysis / Gluconeogenesis
# 1    hsa00020                          Citrate cycle (TCA cycle)
# 2    hsa00030                          Pentose phosphate pathway
# 3    hsa00040           Pentose and glucuronate interconversions
# 4    hsa00051                    Fructose and mannose metabolism
# 5    hsa00052                               Galactose metabolism
# 6    hsa00053                  Ascorbate and aldarate metabolism
# 7    hsa00061                            Fatty acid biosynthesis
# 8    hsa00062                              Fatty acid elongation
# 9    hsa00071                             Fatty acid degradation
# 10   hsa00072         Synthesis and degradation of ketone bodies
# 11   hsa00100                               Steroid biosynthesis
# 12   hsa00120                     Primary bile acid biosynthesis
# 13   hsa00130  Ubiquinone and other terpenoid-quinone biosynt...
# 14   hsa00140                       Steroid hormone biosynthesis
# 15   hsa00190                          Oxidative phosphorylation
# 16   hsa00220                              Arginine biosynthesis
# 17   hsa00230                                  Purine metabolism
# 18   hsa00232                                Caffeine metabolism
# 19   hsa00240                              Pyrimidine metabolism
# 20   hsa00250        Alanine, aspartate and glutamate metabolism
# 21   hsa00260           Glycine, serine and threonine metabolism
# 22   hsa00270                 Cysteine and methionine metabolism
# 23   hsa00280         Valine, leucine and isoleucine degradation
# 24   hsa00290        Valine, leucine and isoleucine biosynthesis
# 25   hsa00310                                 Lysine degradation
# 26   hsa00330                    Arginine and proline metabolism
# 27   hsa00340                               Histidine metabolism
# 28   hsa00350                                Tyrosine metabolism
# 29   hsa00360                           Phenylalanine metabolism
# ..        ...                                                ...
# 288  hsa05210                                  Colorectal cancer
# 289  hsa05211                               Renal cell carcinoma
# 290  hsa05212                                  Pancreatic cancer
# 291  hsa05213                                 Endometrial cancer
# 292  hsa05214                                             Glioma
# 293  hsa05215                                    Prostate cancer
# 294  hsa05216                                     Thyroid cancer
# 295  hsa05217                               Basal cell carcinoma
# 296  hsa05218                                           Melanoma
# 297  hsa05219                                     Bladder cancer
# 298  hsa05220                           Chronic myeloid leukemia
# 299  hsa05221                             Acute myeloid leukemia
# 300  hsa05222                             Small cell lung cancer
# 301  hsa05223                         Non-small cell lung cancer
# 302  hsa05224                                      Breast cancer
# 303  hsa05230                Central carbon metabolism in cancer
# 304  hsa05231                       Choline metabolism in cancer
# 305  hsa05310                                             Asthma
# 306  hsa05320                         Autoimmune thyroid disease
# 307  hsa05321                   Inflammatory bowel disease (IBD)
# 308  hsa05322                       Systemic lupus erythematosus
# 309  hsa05323                               Rheumatoid arthritis
# 310  hsa05330                                Allograft rejection
# 311  hsa05332                          Graft-versus-host disease
# 312  hsa05340                           Primary immunodeficiency
# 313  hsa05410                  Hypertrophic cardiomyopathy (HCM)
# 314  hsa05412  Arrhythmogenic right ventricular cardiomyopath...
# 315  hsa05414                       Dilated cardiomyopathy (DCM)
# 316  hsa05416                                  Viral myocarditis
# 317  hsa05418             Fluid shear stress and atherosclerosis
#
#                                          subclass
# 0                         Carbohydrate metabolism
# 1                         Carbohydrate metabolism
# 2                         Carbohydrate metabolism
# 3                         Carbohydrate metabolism
# 4                         Carbohydrate metabolism
# 5                         Carbohydrate metabolism
# 6                         Carbohydrate metabolism
# 7                                Lipid metabolism
# 8                                Lipid metabolism
# 9                                Lipid metabolism
# 10                               Lipid metabolism
# 11                               Lipid metabolism
# 12                               Lipid metabolism
# 13           Metabolism of cofactors and vitamins
# 14                               Lipid metabolism
# 15                              Energy metabolism
# 16                          Amino acid metabolism
# 17                          Nucleotide metabolism
# 18    Biosynthesis of other secondary metabolites
# 19                          Nucleotide metabolism
# 20                          Amino acid metabolism
# 21                          Amino acid metabolism
# 22                          Amino acid metabolism
# 23                          Amino acid metabolism
# 24                          Amino acid metabolism
# 25                          Amino acid metabolism
# 26                          Amino acid metabolism
# 27                          Amino acid metabolism
# 28                          Amino acid metabolism
# 29                          Amino acid metabolism
# ..                                            ...
# 288                                       Cancers
# 289                                       Cancers
# 290                                       Cancers
# 291                                       Cancers
# 292                                       Cancers
# 293                                       Cancers
# 294                                       Cancers
# 295                                       Cancers
# 296                                       Cancers
# 297                                       Cancers
# 298                                       Cancers
# 299                                       Cancers
# 300                                       Cancers
# 301                                       Cancers
# 302                                       Cancers
# 303                                       Cancers
# 304                                       Cancers
# 305                               Immune diseases
# 306                               Immune diseases
# 307                               Immune diseases
# 308                               Immune diseases
# 309                               Immune diseases
# 310                               Immune diseases
# 311                               Immune diseases
# 312                               Immune diseases
# 313                       Cardiovascular diseases
# 314                       Cardiovascular diseases
# 315                       Cardiovascular diseases
# 316                       Cardiovascular diseases
# 317                       Cardiovascular diseases
#
# [318 rows x 5 columns]

# %%
pathways_df = pathways_df.set_index(['class', 'subclass', 'id'])
pathways_df
# Out:
#                                                                                                                   genes  \
# class          subclass                                     id
# Metabolism      Carbohydrate metabolism                     hsa00010  [HK3, HK1, HK2, HKDC1, GCK, GPI, PFKM, PFKP, P...
#                                                             hsa00020  [CS, ACLY, ACO2, ACO1, IDH1, IDH2, IDH3B, IDH3...
#                                                             hsa00030  [GPI, G6PD, PGLS, H6PD, PGD, RPE, RPEL1, TKT, ...
#                                                             hsa00040  [GUSB, KL, UGT2A1, UGT2A3, UGT2B17, UGT2B11, U...
#                                                             hsa00051  [MPI, PMM2, PMM1, GMPPB, GMPPA, GMDS, TSTA3, F...
#                                                             hsa00052  [GALM, GALK1, GALT, GALE, UGP2, PGM1, PGM2, HK...
#                                                             hsa00053  [UGDH, UGT2A1, UGT2A3, UGT2B17, UGT2B11, UGT2B...
#                 Lipid metabolism                            hsa00061  [ACACA, ACACB, MCAT, FASN, OXSM, OLAH, ACSL6, ...
#                                                             hsa00062  [ACAA2, HADHB, HADH, HADHA, ECHS1, MECR, PPT1,...
#                                                             hsa00071  [ACAT2, ACAT1, ACAA1, ACAA2, HADHB, HADH, HADH...
#                                                             hsa00072  [HMGCS1, HMGCS2, HMGCL, HMGCLL1, OXCT1, OXCT2,...
#                                                             hsa00100  [FDFT1, SQLE, LSS, CYP51A1, TM7SF2, MSMO1, FAX...
#                                                             hsa00120  [CYP46A1, CYP39A1, HSD3B7, CH25H, CYP7B1, CYP7...
#                 Metabolism of cofactors and vitamins        hsa00130  [TAT, COQ2, COQ3, COQ6, COQ5, COQ7, NQO1, GGCX...
#                 Lipid metabolism                            hsa00140  [CYP11A1, CYP17A1, STS, SULT2B1, CYP21A2, HSD3...
#                 Energy metabolism                           hsa00190  [ND1, ND2, ND3, ND4, ND4L, ND5, ND6, NDUFS1, N...
#                 Amino acid metabolism                       hsa00220  [OTC, ASS1, ASL, ARG2, ARG1, NOS1, NOS2, NOS3,...
#                 Nucleotide metabolism                       hsa00230  [NUDT9, ADPRM, NUDT5, PGM1, PGM2, PRPS1L1, PRP...
#                 Biosynthesis of other secondary metabolites hsa00232                  [CYP1A2, NAT2, NAT1, CYP2A6, XDH]
#                 Nucleotide metabolism                       hsa00240  [CAD, DHODH, UMPS, CMPK1, CMPK2, NME6, NME7, N...
#                 Amino acid metabolism                       hsa00250  [GOT1, GOT2, IL4I1, DDO, ASNS, NIT2, GPT2, GPT...
#                                                             hsa00260  [SHMT2, SHMT1, AGXT, GRHPR, GLYCTK, PGAM1, PGA...
#                                                             hsa00270  [CTH, CBS, CBSL, BHMT, BHMT2, MTR, MAT2B, MAT1...
#                                                             hsa00280  [BCAT2, BCAT1, IL4I1, BCKDHA, BCKDHB, DBT, DLD...
#                                                             hsa00290                          [SDS, SDSL, BCAT2, BCAT1]
#                                                             hsa00310  [AASS, ALDH7A1, AADAT, OGDHL, OGDH, DLST, GCDH...
#                                                             hsa00330  [GATM, GAMT, CKM, CKMT1A, CKMT2, CKB, CKMT1B, ...
#                                                             hsa00340  [HAL, UROC1, AMDHD1, FTCD, HDC, DDC, AOC1, ALD...
#                                                             hsa00350  [GOT1, GOT2, TAT, IL4I1, HPD, HGD, GSTZ1, FAH,...
#                                                             hsa00360  [PAH, DDC, AOC3, AOC2, MAOB, MAOA, ALDH3B1, AL...
# ...                                                                                                                 ...
# Human Diseases  Cancers                                     hsa05210  [GSK3B, AXIN1, AXIN2, CTNNB1, APC, APC2, TCF7,...
#                                                             hsa05211  [HIF1A, EPAS1, EGLN1, EGLN3, EGLN2, VHL, ELOC,...
#                                                             hsa05212  [KRAS, PIK3CA, PIK3CD, PIK3CB, PIK3R1, PIK3R2,...
#                                                             hsa05213  [EGF, EGFR, PIK3CA, PIK3CD, PIK3CB, PIK3R1, PI...
#                                                             hsa05214  [EGF, TGFA, EGFR, PDGFA, PDGFB, PDGFRA, PDGFRB...
#                                                             hsa05215  [CDKN1B, CDK2, CCNE1, CCNE2, RB1, E2F1, E2F2, ...
#                                                             hsa05216  [RET, CCDC6, NCOA4, NTRK1, TPM3, TPR, TFG, HRA...
#                                                             hsa05217  [TP53, SHH, PTCH1, SMO, KIF7, SUFU, GLI1, GLI2...
#                                                             hsa05218  [FGF1, FGF2, FGF3, FGF4, FGF17, FGF6, FGF7, FG...
#                                                             hsa05219  [FGFR3, HRAS, KRAS, NRAS, ARAF, BRAF, RAF1, MA...
#                                                             hsa05220  [BCR, ABL1, CRK, CRKL, CBLC, CBL, CBLB, PIK3CA...
#                                                             hsa05221  [KIT, FLT3, PIK3CA, PIK3CD, PIK3CB, PIK3R1, PI...
#                                                             hsa05222  [FHIT, RARB, RXRA, RXRB, RXRG, TP53, BCL2, CYC...
#                                                             hsa05223  [FHIT, RARB, RXRA, RXRB, RXRG, CDKN2A, CDK4, C...
#                                                             hsa05224  [ESR1, ESR2, NCOA1, NCOA3, FOS, JUN, SP1, CCND...
#                                                             hsa05230  [SLC2A1, SLC2A2, GCK, PKM, PDHA2, PDHA1, PDHB,...
#                                                             hsa05231  [EGF, PDGFA, PDGFB, PDGFC, PDGFD, EGFR, PDGFRA...
#                 Immune diseases                             hsa05310  [HLA-DMA, HLA-DMB, HLA-DOA, HLA-DOB, HLA-DPA1,...
#                                                             hsa05320  [IFNA1, IFNA2, IFNA4, IFNA5, IFNA6, IFNA7, IFN...
#                                                             hsa05321  [TLR2, TLR4, TLR5, NFKB1, RELA, NOD2, HLA-DMA,...
#                                                             hsa05322  [C1QA, C1QB, C1QC, C2, C4A, C4B, H2AFX, HIST2H...
#                                                             hsa05323  [CD80, CD86, CD28, CTLA4, HLA-DMA, HLA-DMB, HL...
#                                                             hsa05330  [HLA-A, HLA-B, HLA-C, HLA-F, HLA-G, HLA-E, CD8...
#                                                             hsa05332  [IL6, IL1A, IL1B, TNF, HLA-DMA, HLA-DMB, HLA-D...
#                                                             hsa05340  [ADA, IL7R, IL2RG, DCLRE1C, RAG1, RAG2, CD3D, ...
#                 Cardiovascular diseases                     hsa05410  [ITGA1, ITGA2, ITGA2B, ITGA3, ITGA4, ITGA5, IT...
#                                                             hsa05412  [ITGA1, ITGA2, ITGA2B, ITGA3, ITGA4, ITGA5, IT...
#                                                             hsa05414  [ITGA1, ITGA2, ITGA2B, ITGA3, ITGA4, ITGA5, IT...
#                                                             hsa05416  [CXADR, CD55, FYN, CAV1, ABL1, ABL2, RAC1, RAC...
#                                                             hsa05418  [HSP90AA1, HSP90AB1, HSP90B1, NOS3, CAV1, CAV2...
#
#                                                                                                                    name
# class          subclass                                     id
# Metabolism      Carbohydrate metabolism                     hsa00010                       Glycolysis / Gluconeogenesis
#                                                             hsa00020                          Citrate cycle (TCA cycle)
#                                                             hsa00030                          Pentose phosphate pathway
#                                                             hsa00040           Pentose and glucuronate interconversions
#                                                             hsa00051                    Fructose and mannose metabolism
#                                                             hsa00052                               Galactose metabolism
#                                                             hsa00053                  Ascorbate and aldarate metabolism
#                 Lipid metabolism                            hsa00061                            Fatty acid biosynthesis
#                                                             hsa00062                              Fatty acid elongation
#                                                             hsa00071                             Fatty acid degradation
#                                                             hsa00072         Synthesis and degradation of ketone bodies
#                                                             hsa00100                               Steroid biosynthesis
#                                                             hsa00120                     Primary bile acid biosynthesis
#                 Metabolism of cofactors and vitamins        hsa00130  Ubiquinone and other terpenoid-quinone biosynt...
#                 Lipid metabolism                            hsa00140                       Steroid hormone biosynthesis
#                 Energy metabolism                           hsa00190                          Oxidative phosphorylation
#                 Amino acid metabolism                       hsa00220                              Arginine biosynthesis
#                 Nucleotide metabolism                       hsa00230                                  Purine metabolism
#                 Biosynthesis of other secondary metabolites hsa00232                                Caffeine metabolism
#                 Nucleotide metabolism                       hsa00240                              Pyrimidine metabolism
#                 Amino acid metabolism                       hsa00250        Alanine, aspartate and glutamate metabolism
#                                                             hsa00260           Glycine, serine and threonine metabolism
#                                                             hsa00270                 Cysteine and methionine metabolism
#                                                             hsa00280         Valine, leucine and isoleucine degradation
#                                                             hsa00290        Valine, leucine and isoleucine biosynthesis
#                                                             hsa00310                                 Lysine degradation
#                                                             hsa00330                    Arginine and proline metabolism
#                                                             hsa00340                               Histidine metabolism
#                                                             hsa00350                                Tyrosine metabolism
#                                                             hsa00360                           Phenylalanine metabolism
# ...                                                                                                                 ...
# Human Diseases  Cancers                                     hsa05210                                  Colorectal cancer
#                                                             hsa05211                               Renal cell carcinoma
#                                                             hsa05212                                  Pancreatic cancer
#                                                             hsa05213                                 Endometrial cancer
#                                                             hsa05214                                             Glioma
#                                                             hsa05215                                    Prostate cancer
#                                                             hsa05216                                     Thyroid cancer
#                                                             hsa05217                               Basal cell carcinoma
#                                                             hsa05218                                           Melanoma
#                                                             hsa05219                                     Bladder cancer
#                                                             hsa05220                           Chronic myeloid leukemia
#                                                             hsa05221                             Acute myeloid leukemia
#                                                             hsa05222                             Small cell lung cancer
#                                                             hsa05223                         Non-small cell lung cancer
#                                                             hsa05224                                      Breast cancer
#                                                             hsa05230                Central carbon metabolism in cancer
#                                                             hsa05231                       Choline metabolism in cancer
#                 Immune diseases                             hsa05310                                             Asthma
#                                                             hsa05320                         Autoimmune thyroid disease
#                                                             hsa05321                   Inflammatory bowel disease (IBD)
#                                                             hsa05322                       Systemic lupus erythematosus
#                                                             hsa05323                               Rheumatoid arthritis
#                                                             hsa05330                                Allograft rejection
#                                                             hsa05332                          Graft-versus-host disease
#                                                             hsa05340                           Primary immunodeficiency
#                 Cardiovascular diseases                     hsa05410                  Hypertrophic cardiomyopathy (HCM)
#                                                             hsa05412  Arrhythmogenic right ventricular cardiomyopath...
#                                                             hsa05414                       Dilated cardiomyopathy (DCM)
#                                                             hsa05416                                  Viral myocarditis
#                                                             hsa05418             Fluid shear stress and atherosclerosis
#
# [318 rows x 2 columns]

# %% [markdown]
# ## IV. Normalize Gene Lists

# %%
def flatten(list_of_lists): return [item for sublist in list_of_lists for item in sublist]

# %%
unique_gene_symbols = np.unique(flatten(pathways_df.genes.values))
unique_gene_symbols
# Out:
# array(['A2M', 'A3GALT2', 'A4GALT', ..., 't(8', 't(9', 't(x'],
#       dtype='<U60')

# %%
import mygene
mg = mygene.MyGeneInfo()
df = mg.querymany(unique_gene_symbols.tolist(), scopes=['symbol', 'name', 'alias'], fields=["HGNC", "symbol"], species="hg19", as_dataframe=True, returnall=True)
# Out:
# querying 1-1000...done.
# querying 1001-2000...done.
# querying 2001-3000...done.
# querying 3001-4000...done.
# querying 4001-5000...done.
# querying 5001-6000...done.
# querying 6001-7000...done.
# querying 7001-7235...done.
# Finished.
# 7171 input query terms found dup hits:
# 	[('A2M', 10), ('A3GALT2', 10), ('A4GALT', 10), ('AAAS', 10), ('AACS', 10), ('AADAT', 10), ('AANAT',
# 2 input query terms found no hit:
# 	['DOI:10.1002/1097-0029(20010215)52:4<450::AID-JEMT1030>3.0.CO', 'DOI:10.1002/1521-1878(200008)22:8<

# %%
dup = df['dup']
missing = df['missing']
df = df['out']
df = df[["HGNC", "symbol"]].dropna()
df.head()
# Out:
#           HGNC   symbol
# query
# A2M          7      A2M
# A3GALT2  30005  A3GALT2
# A4GALT   18149   A4GALT
# AAAS     13666     AAAS
# AACS     21298     AACS

# %%
df = df.reset_index().drop_duplicates(subset='query', keep='first').set_index('query').rename_axis(None)
df.head()
# Out:
#           HGNC   symbol
# A2M          7      A2M
# A3GALT2  30005  A3GALT2
# A4GALT   18149   A4GALT
# AAAS     13666     AAAS
# AACS     21298     AACS

# %%
missing
# Out:
# ['DOI:10.1002/1097-0029(20010215)52:4<450::AID-JEMT1030>3.0.CO',
#  'DOI:10.1002/1521-1878(200008)22:8<761::AID-BIES10>3.0.CO']

# %%
len(df[df.index != df.symbol])
# Out:
# 6

# %%
df[df.index != df.symbol]
# Out:
#        HGNC   symbol
# POP3  17649   POPDC3
# t(12  12040   TRAJ12
# t(4   11603     TBX4
# t(8   12096    TRAJ8
# t(9   12097    TRAJ9
# t(x   48335  TCP11X2

# %%
df = df.rename(columns={'symbol':'new_name'})

# %%
pathways_df.index.get_level_values(2)
# Out:
# Index(['hsa00010', 'hsa00020', 'hsa00030', 'hsa00040', 'hsa00051', 'hsa00052',
#        'hsa00053', 'hsa00061', 'hsa00062', 'hsa00071',
#        ...
#        'hsa05322', 'hsa05323', 'hsa05330', 'hsa05332', 'hsa05340', 'hsa05410',
#        'hsa05412', 'hsa05414', 'hsa05416', 'hsa05418'],
#       dtype='object', name='id', length=318)

# %%
pathways_df = pathways_df.sort_index()

# %% [markdown]
# ### Let's quickly get rid of these "Metabolism: Overview" Pathways...

# %%
pathways_df.loc[pd.IndexSlice[['Metabolism'],[' Overview'], :], :]
# Out:
#                               genes                             name
# class      subclass  id
# Metabolism  Overview hsa01200    []                Carbon metabolism
#                      hsa01210    []  2-Oxocarboxylic acid metabolism
#                      hsa01212    []            Fatty acid metabolism
#                      hsa01230    []      Biosynthesis of amino acids

# %%
pathways_df = pathways_df.drop(' Overview', level=1)

# %% [markdown]
# ### Let's remove the bogus genes
# There are only two of them.

# %%
for pathway_id in pathways_df.index.get_level_values(2):
    without_bogus = [gene for gene in pathways_df.loc[pd.IndexSlice[:,:,[pathway_id]], ['genes']].values[0][0] if gene not in missing]
    pathways_df.loc[pd.IndexSlice[:,:,[pathway_id]], ['genes']].values[0][0] = without_bogus

# %% [markdown]
# ### Let's convert the old names to new names...

# %%
for pathway_id in pathways_df.index.get_level_values(2):
    new_names = [df.loc[old_name]['new_name'] for old_name in pathways_df.loc[pd.IndexSlice[:,:,[pathway_id]], ['genes']].values[0][0] if df.index.contains(old_name)]
    pathways_df.loc[pd.IndexSlice[:,:,[pathway_id]], ['genes']].values[0][0] = new_names

# %% [markdown]
# ### Hooray!

# %%
pathways_df.to_pickle('KEGG_df.pickle')
