# %% [markdown]
# # Comparing the performances of L1-Sparse Logistic Regression and Graph-Sparse Logistic Regression on Synthetic Data

# %%
# %pylab inline
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## I. Comparing results on the original resampling synthetic data scheme

# %%
pd.read_pickle('./logit/logit_results.pickle')
